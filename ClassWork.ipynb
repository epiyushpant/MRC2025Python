# %% [markdown]
# # ClassWork

# %% [markdown]
# <h3>Q1. Write a program to create list add elements in list, remove elements from list and display items</h3>

# %%
class ListOperations():
    def __init__(self):
        try:
            list_input = list("Please pass sequence of data.")
            if not isinstance(list_input, list):
                raise TypeError ("Input is not list")
            self.input = list_input
        except Exception as e:
            print(e)
    def add_element(self):
        self.new_list = self.input.append("a,b,c,d")
        return self.new_list
    def remove_element(self):
        new_list = self.input.remove(:3)
        return self.new_list
    def print_list(self):
        print(self.new_list)
listops = ListOperations()
ListOperations.print_list()
