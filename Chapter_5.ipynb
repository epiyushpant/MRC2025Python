# %% [markdown]
# ## Chapter five

# %% [markdown]
# 1. Program to Divide Work in Functions.

# %%
# Function to display a greeting message
def greet():
    print("Welcome to Python Programming!")

# Function to add two numbers
def add(a, b):
    return a + b
def main():
    greet()
    x = int(input("Enter first number: "))
    y = int(input("Enter second number: "))
    result = add(x, y)
    print("Sum =", result)

main()
# Out:
# Welcome to Python Programming!
# Enter first number:  3
# Enter second number:  6
# Sum = 9

# %% [markdown]
# 2.Write different variety of functions: function with arguments, value returning function, function without arguments.

# %%
# Function without arguments
def greet():
    print("Hello from a function without arguments!")

# Function with arguments (no return)
def add(a, b):
    print("Sum is:", a + b)

# Function that returns a value
def multiply(a, b):
    return a * b

# Calling all functions
greet()
add(5, 10)
result = multiply(4, 5)
print("Multiplication Result:", result)
# Out:
# Hello from a function without arguments!
# Sum is: 15
# Multiplication Result: 20

# %% [markdown]
# 3. Write program to store output in file.

# %%
# Function to save data to a file
def save_output():
    result = "This is the data to be saved in file."
    with open("output.txt", "w") as file:
        file.write(result)
    print("Data written to output.txt")

# Call the function
save_output()
# Out:
# Data written to output.txt

# %% [markdown]
# 4. Write program to read input from file.

# %%
def read_input():
    try:
        with open("input.txt", "r") as file:
            data = file.read()
        print("Data from file:", data)
    except FileNotFoundError:
        print("Error: 'input.txt' file not found. Please create the file first.")

# Call the function
read_input()
# Out:
# Error: 'input.txt' file not found. Please create the file first.

# %% [markdown]
# 5. Write program to handle different types of exception.

# %%
try:
    # ZeroDivisionError
    result = 10 / 0
except ZeroDivisionError as zde:
    print(f"Caught ZeroDivisionError: {zde}")

try:
    # ValueError
    num = int("abc")
except ValueError as ve:
    print(f"Caught ValueError: {ve}")

try:
    # IndexError
    lst = [1, 2, 3]
    print(lst[5])
except IndexError as ie:
    print(f"Caught IndexError: {ie}")

try:
    # KeyError
    d = {"a": 1}
    print(d["b"])
except KeyError as ke:
    print(f"Caught KeyError: {ke}")

try:
    # Handling multiple exceptions together
    x = int("xyz")
    y = [1, 2]
    print(y[10])
except (ValueError, IndexError) as e:
    print(f"Caught ValueError or IndexError: {e}")

# Example to show multiple exceptions in a single try block 

try:
    # Attempting to open a non-existent file
    with open('non_existent_file.txt', 'r') as f:
        content = f.read()
except (FileNotFoundError, IOError) as e:
    print(f"Caught FileNotFoundError or IOError: {e}")



# Example of raising an exception
def divide(a, b):
    if b == 0:
        raise ValueError("Cannot divide by zero")
    return a / b
try:
    result = divide(10, 0)
except ValueError as ve:
    print(f"Caught ValueError: {ve}")



# First one errro then generic error 
try:
    # Attempting to convert a string to an integer
    num = int("abc")
except ValueError as ve:
    print(f"Caught ValueError: {ve}")
except Exception as e:
    print(f"Caught a generic exception: {e}")


# Example of handling a specific exception followed by a generic exception

try:
    with open("ghost.txt", "r") as f:
        content = f.read()

except FileNotFoundError as fnfe:
    print(f"Caught FileNotFoundError: {fnfe}")

except Exception as e:
    print(f"Caught generic exception: {e}")


# Example of raise exception with custom message
def check_age(age):
    if age < 0:
        raise ValueError("Age cannot be negative")
    return age
try:    
    age = check_age(-5)
except ValueError as ve:    

    print(f"Caught ValueError: {ve}")
# Out:
# Caught ZeroDivisionError: division by zero
# Caught ValueError: invalid literal for int() with base 10: 'abc'
# Caught IndexError: list index out of range
# Caught KeyError: 'b'
# Caught ValueError or IndexError: invalid literal for int() with base 10: 'xyz'
# Caught FileNotFoundError or IOError: [Errno 2] No such file or directory: 'non_existent_file.txt'
# Caught ValueError: Cannot divide by zero
# Caught ValueError: invalid literal for int() with base 10: 'abc'
# Caught FileNotFoundError: [Errno 2] No such file or directory: 'ghost.txt'
# Caught ValueError: Age cannot be negative
