# %% [markdown]
# ## Chapter four

# %% [markdown]
# 1. Write program to elaborate object oriented concept with simple examples.

# %%
# Object Oriented Programming Example

class Student:
    # Constructor to initialize object
    def __init__(self, name, grade):
        self.name = name
        self.grade = grade

    # Method
    def display_info(self):
        print(f"Name: {self.name}, Grade: {self.grade}")

# Creating objects
student1 = Student("Preeti", "A")
student2 = Student("Ram", "B")

# Accessing methods
student1.display_info()
student2.display_info()
# Out:
# Name: Preeti, Grade: A
# Name: Ram, Grade: B

# %% [markdown]
# 2. Write program to make use of init method to initialize objects.

# %%
class Car:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def show(self):
        print(f"Car Brand: {self.brand}, Model: {self.model}")

# Creating objects
car1 = Car("Toyota", "Corolla")
car2 = Car("Tesla", "Model S")

car1.show()
car2.show()
# Out:
# Car Brand: Toyota, Model: Corolla
# Car Brand: Tesla, Model: Model S

# %% [markdown]
# 3. Write program to apply different types of inheritance.

# %% [markdown]
# ## single inheritance

# %%
class Animal:
    def speak(self):
        print("Animal speaks")

class Dog(Animal):
    def bark(self):
        print("Dog barks")

d = Dog()
d.speak()
d.bark()
# Out:
# Animal speaks
# Dog barks

# %% [markdown]
# ## Multiple Inheritance

# %%
class Father:
    def skill(self):
        print("Farming")

class Mother:
    def talent(self):
        print("Singing")

class Child(Father, Mother):
    def hobby(self):
        print("Drawing")

c = Child()
c.skill()
c.talent()
c.hobby()
# Out:
# Farming
# Singing
# Drawing

# %% [markdown]
# ## Multi Level inheritance

# %%
class Grandparent:
    def say_hi(self):
        print("Hi from Grandparent")

class Parent(Grandparent):
    def say_hello(self):
        print("Hello from Parent")



class Child(Parent):
    def say_bye(self):
        print("Bye from Child")

obj = Child()
obj.say_hi()
obj.say_hello()
obj.say_bye()
# Out:
# Hi from Grandparent
# Hello from Parent
# Bye from Child

# %% [markdown]
# ## Hierarchical inheritance

# %%
class Animal:
    def speak(self):
        print("Animal speaks")

class Dog(Animal):
    def bark(self):
        print("Dog barks")

class Cat(Animal):
    def meow(self):
        print("Cat meows")

d = Dog()
d.speak()
d.bark()

c = Cat()
c.speak()
c.meow()
# Out:
# Animal speaks
# Dog barks
# Animal speaks
# Cat meows

# %% [markdown]
# ## Hybrid inheritance

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def show_person(self):
        print(f"Name: {self.name}, Age: {self.age}")

class Employee(Person):
    def __init__(self, name, age, employee_id):
        super().__init__(name, age)
        self.employee_id = employee_id

    def show_employee(self):
        print(f"Employee ID: {self.employee_id}")

class Manager(Employee):
    def __init__(self, name, age, employee_id, team_size):
        super().__init__(name, age, employee_id)
        self.team_size = team_size

    def show_manager(self):
        print(f"Manages a team of {self.team_size} people")

# Usage
mgr = Manager("Alice", 35, "E123", 10)
mgr.show_person()     # From Person class
mgr.show_employee()   # From Employee class
mgr.show_manager()    # From Manager class
# Out:
# Name: Alice, Age: 35
# Employee ID: E123
# Manages a team of 10 people

# %% [markdown]
# 4. Write program to elaborate polymorphism and data hiding concept using.

# %% [markdown]
# ## Polymorphism using Method Overriding.

# %%
class Employee:
    def salary(self):
        print("Base salary")

class Manager(Employee):
    def salary(self):
        print("Manager salary with bonus")

m = Manager()
m.salary()  # Output: Manager salary with bonus
# Out:
# Manager salary with bonus

# %% [markdown]
# ## Data Hiding (Encapsulation)

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance  # private variable

    def deposit(self, amount):
        self.__balance += amount

    def show_balance(self):
        print("Current Balance:", self.__balance)

acc = BankAccount(1000)
acc.deposit(500)
acc.show_balance()
# Out:
# Current Balance: 1500
