# %%
# Arithmetic Operators
a = 14
b = 3

print("Arithmetic Operators:")
print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")
print(f"Floor Division: {a} // {b} = {a // b}")
print(f"Modulus: {a} % {b} = {a % b}")
print(f"Exponentiation: {a} ** {b} = {a ** b}")
# Out:
# Arithmetic Operators:
# Addition: 14 + 3 = 17
# Subtraction: 14 - 3 = 11
# Multiplication: 14 * 3 = 42
# Division: 14 / 3 = 4.666666666666667
# Floor Division: 14 // 3 = 4
# Modulus: 14 % 3 = 2
# Exponentiation: 14 ** 3 = 2744

# %%
# Comparison Operators
x = 10
y = 20

print("\nComparison Operators:")
print(f"x == y: {x == y}")
print(f"x != y: {x != y}")
print(f"x > y: {x > y}")
print(f"x < y: {x < y}")
print(f"x >= y: {x >= y}")
print(f"x <= y: {x <= y}")
# Out:
# Comparison Operators:
# x == y: False
# x != y: True
# x > y: False
# x < y: True
# x >= y: False
# x <= y: True

# %%
# Logical Operators
p = True
q = False

print("\nLogical Operators:")
print(f"p and q: {p and q}")
print(f"p or q: {p or q}")
print(f"not p: {not p}")
# Out:
# Logical Operators:
# p and q: False
# p or q: True
# not p: False

# %%
# Assignment Operators
z = 5
z += 3  # z = z + 3
print("\nAssignment Operators:")
print(f"z += 3: {z}")

z *= 2  # z = z * 2
print(f"z *= 2: {z}")
# Out:
# Assignment Operators:
# z += 3: 8
# z *= 2: 16

# %%
# Bitwise Operators
a = 10  # 1010 in binary
b = 4   # 0100 in binary

print("\nBitwise Operators:")
print(f"a & b: {a & b}")  # AND
print(f"a | b: {a | b}")  # OR
print(f"a ^ b: {a ^ b}")  # XOR
print(f"~a: {~a}")         # NOT
print(f"a << 1: {a << 1}")  # Left shift  -- insert 0 in last 
print(f"a >> 1: {a >> 1}")  # Right shift -- insert 0 in first and shifts
# Out:
# Bitwise Operators:
# a & b: 0
# a | b: 14
# a ^ b: 14
# ~a: -11
# a << 1: 20
# a >> 1: 5

# %%
a = 10  # Binary: 1010
print(a << 1)  # Output: 20 (Binary: 10100) : insert 0 in last (left shift) 
print(a << 2)  # Output: 40 (Binary: 101000) : 1010 -> insert 2 0's in last
# Out:
# 20
# 40

# %%
a = 10  # Binary: 1010
print(a >> 1)  # Output: 5 (Binary: 0101) : insert 0  in front ( right shift ) 
print(a >> 2)  # Output: 2 (Binary: 0010)
# Out:
# 5
# 2

# %% [markdown]
# ### Membership operators check if a value is present in a sequence like lists, tuples, or strings.
#
# in → Returns **True** if the specified element exists in the sequence.
#
# not in → Returns **True** if it does not exist in the sequence.

# %%
# Membership Operators
lst = [1, 2, 3, 4, 5]
tup = (1,5)
text = "Hello, world!"

print("\nMembership Operators:")
print(f"3 in lst: {7 in lst}")
print(f"3 in tuple: {3 in tup}")
print(f"6 not in lst: {6 not in lst}")

print("Hello" in text)    # Output: True
print("Python" in text)   # Output: False
print("world" not in text) # Output: False
# Out:
# Membership Operators:
# 3 in lst: False
# 3 in tuple: False
# 6 not in lst: True
# True
# False
# False

# %% [markdown]
# ### Identity operators are used to compare whether two objects refer to the same memory location.
#
# is → Returns **True** if both variables reference the same object.
#
# is not → Returns **True** if they reference different object

# %%
# Identity Operators
a = [1, 2, 3]
b = [1, 2, 3]
c = a

print("\nIdentity Operators:")
print(f"a is b: {a is b}")    # False, because a and b are different objects
print(f"a is c: {a is c}")    # True, because a and c refer to the same object
# Out:
# Identity Operators:
# a is b: False
# a is c: True

# %%
class myclass():
  def __len__(self):
    return 0

myobj = myclass()
print(bool(myobj))
# Out:
# False

# %%
def myFunction() :
  return 0

print(bool(myFunction()))
# Out:
# False
